# %%
###
# App Name:  Creating fake data of 50 projects
# App URI: https://opendatabim.io/
# Description: Creating fake data of 50 projects, with data based on the 
# first four files, to show the possibility of creating a model for predicting 
# project prices, which will be based on the company's 50 projects
# OpenDataBIM
# This program is free software: you can redistribute it and/or modify
# it under the terms of the GNU General Public License as published by
# the Free Software Foundation, either version 3 of the License, or
# (at your option) any later version.
###

# %%
#loading nessary libs
import pandas as pd
from sklearn import preprocessing
import random
import json
import numpy as np

# %%
#define constants
THRESHOLD = .7      #minimal level of  NAN-values in thr field. If it less than THRESHOLD this field will be remove from dataset 
NUM_OF_FILES = 50   #quantity of output files
NUM_OF_ROWS = 269   #quantity of rows in generated file
CAT_PURE_OUT = False #True - categorical data saving out as pure, False - as encoded

# %%
#import source file
df = pd.read_csv('source.csv', low_memory=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Columns: 138 entries, feature_1 to Interior Type
# dtypes: float64(65), int64(1), object(72)
# memory usage: 290.1+ KB

# %%
#sample of source file
df.sample(6)
# Out:
#      feature_1 Design Option                 Category  \
# 3     10445184          None               OST_Fascia
# 89    10428925          None  OST_CurtainWallMullions
# 187   10885923          None              OST_Windows
# 259   10899334          None                OST_Walls
# 247   10348085          None                OST_Walls
# 31    10446357          None     OST_PlumbingFixtures
#
#                             Family                           Type  \
# 3                           Fascia                         Fascia
# 89                         38x76mm                        38x76mm
# 187  WK - Three Panel Window 600mm  WK - Three Panel Window 600mm
# 259                        plaster                        plaster
# 247                     Mesh Fence                     Mesh Fence
# 31        CAMPINES BASIN 540 x 405       CAMPINES BASIN 540 x 405
#
#      Horizontal Profile Offset  Vertical Profile Offset    Length  \
# 3                          0.0                   -200.0  127094.0
# 89                         NaN                      NaN      54.0
# 187                        NaN                      NaN       NaN
# 259                        NaN                      NaN    4851.0
# 247                        NaN                      NaN    2184.0
# 31                         NaN                      NaN       NaN
#
#                    Family and Type                        Type Id  ... Number  \
# 3                           Fascia                         Fascia  ...    NaN
# 89                         38x76mm                        38x76mm  ...    NaN
# 187  WK - Three Panel Window 600mm  WK - Three Panel Window 600mm  ...    NaN
# 259                        plaster                        plaster  ...    NaN
# 247                     Mesh Fence                     Mesh Fence  ...    1.0
# 31        CAMPINES BASIN 540 x 405       CAMPINES BASIN 540 x 405  ...    NaN
#
#     Automatically Embed Curtain Panel Join Condition Adjust for Mullion Size  \
# 3                   NaN           NaN            NaN                     NaN
# 89                  NaN           NaN            NaN                     NaN
# 187                 NaN           NaN            NaN                     NaN
# 259                 NaN           NaN            NaN                     NaN
# 247                  No       Fencing            0.0                     Yes
# 31                  NaN           NaN            NaN                     NaN
#
#     Layout Spacing Border 1 Type  Border 2 Type  Interior Type
# 3      NaN     NaN           NaN            NaN            NaN
# 89     NaN     NaN           NaN            NaN            NaN
# 187    NaN     NaN           NaN            NaN            NaN
# 259    NaN     NaN           NaN            NaN            NaN
# 247    1.0  1800.0       38x76mm        38x76mm           None
# 31     NaN     NaN           NaN            NaN            NaN
#
# [6 rows x 138 columns]

# %%
#for digital fields replacing NAN to mean value
for clm in df.columns:
    if df[clm].dtypes =='float64':
        df[clm] = df[clm].fillna(df[clm].mean())

# %%
#checking dataset condition
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Columns: 138 entries, feature_1 to Interior Type
# dtypes: float64(65), int64(1), object(72)
# memory usage: 290.1+ KB

# %%
#removing fields with quntity of NAN, more than threshold
drop_thresh = df.shape[0] * THRESHOLD
df = df.dropna(thresh=drop_thresh, how='all', axis='columns')

# %%
#replacing missing value to random value for categorical fields
for clm in [clm for clm in df.columns if df[clm].dtypes == 'O']:
    if df[clm].isna().sum() > 0:
        print(clm)
        df[clm] = df[clm].fillna(random.choice(df[clm]))
# Out:
# Family
# Type
# Family and Type
# Type Id
# Phase Created
# Phase Demolished
# Type Name
# Family Name
# Volume
# Area

# %%
#Making lists of true categorical and single-value fields.Removing single-value fields.
true_categorical = [clm for clm in df.columns if df[clm].dtypes == 'O' and len(df[clm].unique()) > 1]
true_categorical.append('feature_1')
single_value =  [clm for clm in df.columns if len(df[clm].unique()) == 1]
df = df.drop(single_value, axis=1)

# %%
#checking dataset condition
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   feature_1                   269 non-null    int64
#  1   Category                    269 non-null    object
#  2   Family                      269 non-null    object
#  3   Type                        269 non-null    object
#  4   Length                      269 non-null    float64
#  5   Family and Type             269 non-null    object
#  6   Type Id                     269 non-null    object
#  7   Type Name                   269 non-null    object
#  8   Family Name                 265 non-null    object
#  9   Base Offset                 269 non-null    float64
#  10  Top Offset                  269 non-null    float64
#  11  Volume                      269 non-null    object
#  12  Structural Material         269 non-null    float64
#  13  Area                        269 non-null    object
#  14  Elevation at Bottom         269 non-null    float64
#  15  Elevation at Bottom Survey  269 non-null    float64
#  16  Elevation at Top            269 non-null    float64
#  17  Elevation at Top Survey     269 non-null    float64
#  18  Width                       269 non-null    float64
#  19  Foundation Thickness        269 non-null    float64
#  20  Structural Usage            269 non-null    float64
#  21  Elevation from Level        269 non-null    float64
#  22  Offset                      269 non-null    float64
#  23  Mark                        269 non-null    float64
#  24  Thickness                   269 non-null    float64
#  25  Unconnected Height          269 non-null    float64
#  26  Base Offset From Level      269 non-null    float64
#  27  Maximum Ridge Height        269 non-null    float64
#  28  Absorptance                 269 non-null    float64
#  29  Default Thickness           269 non-null    float64
#  30  Coarse Scale Fill Color     269 non-null    float64
#  31  Height Offset From Level    269 non-null    float64
#  32  Perimeter                   269 non-null    float64
#  33  Sill Height                 269 non-null    float64
#  34  Head Height                 269 non-null    float64
#  35  Wall Closure                269 non-null    float64
#  36  Panel Width                 269 non-null    float64
#  37  Location Line               269 non-null    float64
#  38  Number                      269 non-null    float64
# dtypes: float64(29), int64(1), object(9)
# memory usage: 82.1+ KB

# %%
#define Label encoder, making encoder values maping.
le = preprocessing.LabelEncoder()
le_maping = {}
for clm in true_categorical:
    df[clm] = le.fit_transform(df[clm])
    le_maping[clm] = dict(zip(le.transform(le.classes_), le.classes_))

# %%
#Saving maping to the file
np.save('le_maping.npy', le_maping) 

#For decode mapind from file use this constraction
#le_maping = np.load('le_maping.npy',allow_pickle='TRUE').item()

# %%
#checking dataset condition
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   feature_1                   269 non-null    int64
#  1   Category                    269 non-null    int32
#  2   Family                      269 non-null    int32
#  3   Type                        269 non-null    int32
#  4   Length                      269 non-null    float64
#  5   Family and Type             269 non-null    int32
#  6   Type Id                     269 non-null    int32
#  7   Type Name                   269 non-null    int32
#  8   Family Name                 269 non-null    int32
#  9   Base Offset                 269 non-null    float64
#  10  Top Offset                  269 non-null    float64
#  11  Volume                      269 non-null    int32
#  12  Structural Material         269 non-null    float64
#  13  Area                        269 non-null    int32
#  14  Elevation at Bottom         269 non-null    float64
#  15  Elevation at Bottom Survey  269 non-null    float64
#  16  Elevation at Top            269 non-null    float64
#  17  Elevation at Top Survey     269 non-null    float64
#  18  Width                       269 non-null    float64
#  19  Foundation Thickness        269 non-null    float64
#  20  Structural Usage            269 non-null    float64
#  21  Elevation from Level        269 non-null    float64
#  22  Offset                      269 non-null    float64
#  23  Mark                        269 non-null    float64
#  24  Thickness                   269 non-null    float64
#  25  Unconnected Height          269 non-null    float64
#  26  Base Offset From Level      269 non-null    float64
#  27  Maximum Ridge Height        269 non-null    float64
#  28  Absorptance                 269 non-null    float64
#  29  Default Thickness           269 non-null    float64
#  30  Coarse Scale Fill Color     269 non-null    float64
#  31  Height Offset From Level    269 non-null    float64
#  32  Perimeter                   269 non-null    float64
#  33  Sill Height                 269 non-null    float64
#  34  Head Height                 269 non-null    float64
#  35  Wall Closure                269 non-null    float64
#  36  Panel Width                 269 non-null    float64
#  37  Location Line               269 non-null    float64
#  38  Number                      269 non-null    float64
# dtypes: float64(29), int32(9), int64(1)
# memory usage: 72.6 KB

# %%
df['price'] = random.uniform(115000, 370000)

# %%
#sample of target dataset
df.sample(11)
# Out:
#      feature_1  Category  Family  Type       Length  Family and Type  Type Id  \
# 217        123        17       5     5  6604.000000                5        5
# 243        183        17       1     1   530.000000                1        1
# 93         191         2       6     6  1715.000000                6        6
# 171        117         4      22    22  3553.267442               22       22
# 25         215        16      13    13  5600.000000               13       13
# 120        187         3      26    26  3553.267442               26       26
# 54          42         2       6     6  1571.000000                6        6
# 147        130        11      52    52  3553.267442               52       52
# 200         15        17       5     5  1900.000000                5        5
# 225         20        17       1     1  3550.000000                1        1
# 227         22        17       1     1  3550.000000                1        1
#
#      Type Name  Family Name  Base Offset  ...  Coarse Scale Fill Color  \
# 217          5            3  -600.000000  ...                      0.0
# 243          1            3     0.000000  ...                      0.0
# 93           6           24    36.206897  ...                 197379.0
# 171         22           21    36.206897  ...                 197379.0
# 25          13           35    36.206897  ...                 197379.0
# 120         26           31    36.206897  ...                 197379.0
# 54           6           24    36.206897  ...                 197379.0
# 147         52            2    36.206897  ...                      0.0
# 200          5            3 -1200.000000  ...                      0.0
# 225          1            3     0.000000  ...                      0.0
# 227          1            3     0.000000  ...                      0.0
#
#      Height Offset From Level     Perimeter  Sill Height  Head Height  \
# 217                431.666667  38455.333333    429.62963  1953.148148
# 243                431.666667  38455.333333    429.62963  1953.148148
# 93                 431.666667  38455.333333    429.62963  1953.148148
# 171                431.666667  38455.333333    900.00000  3050.000000
# 25                 431.666667  38455.333333    429.62963  1953.148148
# 120                431.666667  38455.333333    429.62963  1953.148148
# 54                 431.666667  38455.333333    429.62963  1953.148148
# 147                431.666667  38455.333333    429.62963  1953.148148
# 200                431.666667  38455.333333    429.62963  1953.148148
# 225                431.666667  38455.333333    429.62963  1953.148148
# 227                431.666667  38455.333333    429.62963  1953.148148
#
#      Wall Closure  Panel Width  Location Line  Number          price
# 217      0.153846   887.888889       2.000000    2.75  150175.989714
# 243      0.153846   887.888889       2.000000    2.75  150175.989714
# 93       0.153846   887.888889       1.888889    2.75  150175.989714
# 171      4.000000   887.888889       1.888889    2.75  150175.989714
# 25       0.153846   887.888889       1.888889    2.75  150175.989714
# 120      0.153846   887.888889       1.888889    2.75  150175.989714
# 54       0.153846   887.888889       1.888889    2.75  150175.989714
# 147      0.153846   887.888889       1.888889    2.75  150175.989714
# 200      0.153846   887.888889       2.000000    2.75  150175.989714
# 225      0.153846   887.888889       2.000000    2.75  150175.989714
# 227      0.153846   887.888889       2.000000    2.75  150175.989714
#
# [11 rows x 40 columns]

# %%
#saving taget dataset to file
df.to_csv('0_1house_R.csv', index=False)

# %%
#Generating NUM_OF_FILES files, replacing categorical values to random choise from field, real values to random values from appropriate range
for i in range(NUM_OF_FILES):
    print('Preparing files:', i)
    tmp_df = pd.DataFrame()
    price = random.uniform(115000, 370000)
    for clm in df.columns:
        min_bound, max_baound = df[clm].min(), df[clm].max()
        if clm in true_categorical:
            tmp_df[clm] = random.sample(df[clm].tolist(), NUM_OF_ROWS)
            if CAT_PURE_OUT:
                tmp_df = tmp_df.replace({clm:le_maping[clm]})
        else:
            tmp_df[clm] = [random.uniform(min_bound, max_baound) for val in range (0, NUM_OF_ROWS)]                 
    tmp_df['price'] = NUM_OF_ROWS * [price]    
    tmp_df.to_csv(str(i + 1) + '_1house_R.csv', index=False)
    print('Saving files:', i, ' - OK')
    print()
# Out:
# Preparing files: 0
# Saving files: 0  - OK
#
# Preparing files: 1
# Saving files: 1  - OK
#
# Preparing files: 2
# Saving files: 2  - OK
#
# Preparing files: 3
# Saving files: 3  - OK
#
# Preparing files: 4
# Saving files: 4  - OK
#
# Preparing files: 5
# Saving files: 5  - OK
#
# Preparing files: 6
# Saving files: 6  - OK
#
# Preparing files: 7
# Saving files: 7  - OK
#
# Preparing files: 8
# Saving files: 8  - OK
#
# Preparing files: 9
# Saving files: 9  - OK
#
# Preparing files: 10
# Saving files: 10  - OK
#
# Preparing files: 11
# Saving files: 11  - OK
#
# Preparing files: 12
# Saving files: 12  - OK
#
# Preparing files: 13
# Saving files: 13  - OK
#
# Preparing files: 14
# Saving files: 14  - OK
#
# Preparing files: 15
# Saving files: 15  - OK
#
# Preparing files: 16
# Saving files: 16  - OK
#
# Preparing files: 17
# Saving files: 17  - OK
#
# Preparing files: 18
# Saving files: 18  - OK
#
# Preparing files: 19
# Saving files: 19  - OK
#
# Preparing files: 20
# Saving files: 20  - OK
#
# Preparing files: 21
# Saving files: 21  - OK
#
# Preparing files: 22
# Saving files: 22  - OK
#
# Preparing files: 23
# Saving files: 23  - OK
#
# Preparing files: 24
# Saving files: 24  - OK
#
# Preparing files: 25
# Saving files: 25  - OK
#
# Preparing files: 26
# Saving files: 26  - OK
#
# Preparing files: 27
# Saving files: 27  - OK
#
# Preparing files: 28
# Saving files: 28  - OK
#
# Preparing files: 29
# Saving files: 29  - OK
#
# Preparing files: 30
# Saving files: 30  - OK
#
# Preparing files: 31
# Saving files: 31  - OK
#
# Preparing files: 32
# Saving files: 32  - OK
#
# Preparing files: 33
# Saving files: 33  - OK
#
# Preparing files: 34
# Saving files: 34  - OK
#
# Preparing files: 35
# Saving files: 35  - OK
#
# Preparing files: 36
# Saving files: 36  - OK
#
# Preparing files: 37
# Saving files: 37  - OK
#
# Preparing files: 38
# Saving files: 38  - OK
#
# Preparing files: 39
# Saving files: 39  - OK
#
# Preparing files: 40
# Saving files: 40  - OK
#
# Preparing files: 41
# Saving files: 41  - OK
#
# Preparing files: 42
# Saving files: 42  - OK
#
# Preparing files: 43
# Saving files: 43  - OK
#
# Preparing files: 44
# Saving files: 44  - OK
#
# Preparing files: 45
# Saving files: 45  - OK
#
# Preparing files: 46
# Saving files: 46  - OK
#
# Preparing files: 47
# Saving files: 47  - OK
#
# Preparing files: 48
# Saving files: 48  - OK
#
# Preparing files: 49
# Saving files: 49  - OK

# %%
[random.uniform(115000, 370000)]
# Out:
# [271032.7861785048]
